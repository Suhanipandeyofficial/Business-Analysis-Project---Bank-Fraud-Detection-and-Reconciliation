# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhanipandeyofficial/Business-Analysis-Project---Bank-Fraud-Detection-and-Reconciliation/blob/main/Case_1_(Retail).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =====================================================
# Import required libraries (run once at the top)
# =====================================================
import pandas as pd
import matplotlib.pyplot as plt

# Set option to display all rows (None means unlimited)
pd.set_option('display.max_rows', None) # This option tells Pandas to display all rows of a DataFrame without truncation when printed. Setting it to `None` disables the row limit, showing every row of the DataFrame.

# Also useful for displaying all columns
pd.set_option('display.max_columns', None)

# %%
# =====================================================
# Load the dataset: Note the file type is  .csv , hence, read_csv has been used; For .xlsx read_excelwill be used
# =====================================================
df = pd.read_csv('orders_2025.csv')

# %%
# Q1. How many rows and how many columns are present in the dataset?
# =====================================================
# Step 1: Check dataset shape
df.shape
# Out:
# (1500, 11)

# %%
# Q2. What kind of data has been provided?
# =====================================================
# Step 1: Understand column types and structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1500 non-null   object
#  1   Customerid    1500 non-null   object
#  2   Amount        1500 non-null   int64
#  3   Profit        1500 non-null   int64
#  4   Quantity      1500 non-null   int64
#  5   Category      1500 non-null   object
#  6   Sub-Category  1500 non-null   object
#  7   PaymentMode   1500 non-null   object
#  8   State         1500 non-null   object
#  9   City          1500 non-null   object
#  10  Pincode       4 non-null      float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 129.0+ KB

# %%
# Step 2: Inspect sample rows (default is top 5 rows)
df.head()
# Out:
#   Order ID Customerid  Amount  Profit  Quantity     Category  \
# 0  B-25681      Cust1    1096     658         7  Electronics
# 1  B-25682      Cust2    5729      64        14    Furniture
# 2  B-25683      Cust3    2927     146         8    Furniture
# 3  B-25684      Cust4    2847     712         8  Electronics
# 4  B-25685      Cust5    2617    1151         4  Electronics
#
#        Sub-Category  PaymentMode           State     City  Pincode
# 0  Electronic Games          COD  Madhya Pradesh   Indore      NaN
# 1            Chairs          EMI   Uttar Pradesh  Mathura      NaN
# 2         Bookcases          EMI     Maharashtra     Pune      NaN
# 3          Printers  Credit Card     Maharashtra     Pune      NaN
# 4            Phones  Credit Card     Maharashtra     Pune      NaN

# %%
# Step 3: Inspect sample rows (top 20)
df.head(20)
# Out:
#    Order ID Customerid  Amount  Profit  Quantity     Category  \
# 0   B-25681      Cust1    1096     658         7  Electronics
# 1   B-25682      Cust2    5729      64        14    Furniture
# 2   B-25683      Cust3    2927     146         8    Furniture
# 3   B-25684      Cust4    2847     712         8  Electronics
# 4   B-25685      Cust5    2617    1151         4  Electronics
# 5   B-25686      Cust6    2244     247         4     Clothing
# 6   B-25687      Cust6     275    -275         4     Clothing
# 7   B-25688      Cust6     387    -213         5     Clothing
# 8   B-25689      Cust6      50     -44         2     Clothing
# 9   B-25690      Cust6     135     -54         5     Clothing
# 10  B-25691      Cust6     231    -190         9     Clothing
# 11  B-25692      Cust7    2125    -234         6  Electronics
# 12  B-25693      Cust8    3873    -891         6  Electronics
# 13  B-25694      Cust9     729    -492         5    Furniture
# ...

# %%
# Step 4: Inspect sample rows (bottom 20)
df.head(-20)
# Out:
#      Order ID Customerid  Amount  Profit  Quantity     Category  \
# 0     B-25681      Cust1    1096     658         7  Electronics
# 1     B-25682      Cust2    5729      64        14    Furniture
# 2     B-25683      Cust3    2927     146         8    Furniture
# 3     B-25684      Cust4    2847     712         8  Electronics
# 4     B-25685      Cust5    2617    1151         4  Electronics
# 5     B-25686      Cust6    2244     247         4     Clothing
# 6     B-25687      Cust6     275    -275         4     Clothing
# 7     B-25688      Cust6     387    -213         5     Clothing
# 8     B-25689      Cust6      50     -44         2     Clothing
# 9     B-25690      Cust6     135     -54         5     Clothing
# 10    B-25691      Cust6     231    -190         9     Clothing
# 11    B-25692      Cust7    2125    -234         6  Electronics
# 12    B-25693      Cust8    3873    -891         6  Electronics
# 13    B-25694      Cust9     729    -492         5    Furniture
# ...

# %%
# Q3. How many orderids are present? Is the data unique on the Order ID?
# =====================================================
# Step 1: Count total Order IDs
total_orders = df['Order ID'].count()
print("Total Order IDs:", total_orders)
# Out:
# Total Order IDs: 1500

# %%
# Step 2: Count unique Order IDs
unique_orders = df['Order ID'].nunique()
print("Unique Order IDs:", unique_orders)
# Out:
# Unique Order IDs: 1500

# %%
# Q4. How many customerids are present? Is the data unique on the Customerid?
# =====================================================
# Step 1: Count customer IDs
total_customerid=df['Customerid'].count()
print("Total Customerid:", total_customerid)
# Out:
# Total Customerid: 1500

# %%
# Step 2: Count unique Order IDs
unique_customerid=df['Customerid'].nunique()
print("Unique Customerids:", unique_customerid)
# Out:
# Unique Customerids: 1449
